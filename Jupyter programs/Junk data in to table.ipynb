"is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Sunny  Singh", "phone_number": "9798383834", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Aniket  Mohit", "phone_number": "9507567334", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "SUMESH  KUMAR", "phone_number": "9693018743", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Arun  K", "phone_number": "9798926157", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "BHARAT  ENTERPRI", "phone_number": "9113461539", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Dilip  Kumar", "phone_number": "9653435325", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Pawan  kr", "phone_number": "8660032229", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Harshit  Anand", "phone_number": "7779834858", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Nawal  kishorjha", "phone_number": "9431025063", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Raj  Kamal", "phone_number": "9430573692", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Amit  Mishra", "phone_number": "7004515865", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Pushp  Shekhar", "phone_number": "9162683713", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "RANJIT  KUMAR", "phone_number": "7870443079", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Suman  Singh", "phone_number": "8310241212", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Deo  singh", "phone_number": "9334115262", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Pallawi  K", "phone_number": "7761943859", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Rajesh  Kumar", "phone_number": "9431200289", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Pranesh  Sinha", "phone_number": "8709314780", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Vinay  Kumar", "phone_number": "9504949474", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "JUTENDRA  KUMAR", "phone_number": "9108275385", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "S  N", "phone_number": "7004372039", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Ashutosh  Prasad", "phone_number": "9654422590", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Ashiana  Auto", "phone_number": "8271617126", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Deepak  kumar", "phone_number": "9006233584", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Raj  kumar", "phone_number": "9771404554", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "MOHAN  KUMAR", "phone_number": "9199235021", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Shobha  shobha", "phone_number": "9631755388", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Bagish  Pandey", "phone_number": "7903830633", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Anish  Kumar", "phone_number": "8271355355", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "EXULTED  SOLUTIO", "phone_number": "8235779011", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "PRADEEP  KUMAR", "phone_number": "7488447926", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "AJAY  KUMAR", "phone_number": "8709961871", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Sarika  Kumari", "phone_number": "9507952007", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Priyanka  Kumari", "phone_number": "7488611649", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Vijay  Kumar", "phone_number": "9334113067", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "SHANTAM  AGRAWAL", "phone_number": "8879111380", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"},
{"aadhar_number": "null", "pan_number": "null", "first_name": "null", "last_name": "null", "full_name": "Parul  Parul", "phone_number": "9560661405", "is_aadhar": "null", "operator_phone_number": "null", "date_of_birth": "null", "is_chassis": "false"}

]
data1=pd.DataFrame(data1)
data1
# Out:
#    aadhar_number pan_number first_name last_name         full_name  \
# 0           null       null       null      null   Sayantan  Ghosh
# 1           null       null       null      null     Niraj  Nirala
# 2           null       null       null      null    Shubhanker  KR
# 3           null       null       null      null            Dr  Md
# 4           null       null       null      null    Pramila  Gupta
# ..           ...        ...        ...       ...               ...
# 94          null       null       null      null    Sarika  Kumari
# 95          null       null       null      null  Priyanka  Kumari
# 96          null       null       null      null      Vijay  Kumar
# 97          null       null       null      null  SHANTAM  AGRAWAL
# 98          null       null       null      null      Parul  Parul
#
#    phone_number is_aadhar operator_phone_number date_of_birth is_chassis
# 0    8902401720      null                  null          null      false
# ...

# %%
data1.to_excel("data_table.xlsx",index=False)
data1.to_csv("data_table.csv",index=False)

# %%
import pandas as pd
data=[{
    'Name':'Indrajeet',
    'father Name':'charan singh'
}]
data=pd.DataFrame(data)
data
# Out:
#         Name   father Name
# 0  Indrajeet  charan singh
