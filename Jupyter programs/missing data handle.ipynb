# %%
import pandas as pd
data=pd.read_csv(r"data weather.csv",parse_dates=["EST"])
data
# Out:
#     Unnamed: 0        EST  Temperature  DewPoint  Humidity  \
# 0            0 2016-01-01           38        23        52
# 1            1 2016-01-02           36        18        46
# 2            2 2016-01-03           40        21        47
# 3            3 2016-01-04           25         9        44
# 4            4 2016-01-05           20        -3        41
# 5            5 2016-01-06           33         4        35
# 6            6 2016-01-07           39        11        33
# 7            7 2016-01-08           39        29        64
# 8            8 2016-01-09           44        38        77
# 9            9 2016-01-10           50        46        71
# 10          10 2016-01-11           33         8        37
# 11          11 2016-01-12           35        15        53
# 12          12 2016-01-13           26         4        42
# 13          13 2016-01-14           30        12        47
# 14          14 2016-01-15           43        31        62
# ...
