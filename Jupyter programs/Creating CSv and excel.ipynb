# %%
import pandas as pd
data=pd.read_csv('dispatch_data.csv',dtype=object,nrows=5)
data.fillna('-',inplace=True)
data
# Out:
#    Order ID Forward ID Shiprocket Created At Channel     Status  \
# 0  19663366          -    1 Dec 22, 10:40 AM  CUSTOM  DELIVERED
# 1  19663366          -    1 Dec 22, 10:40 AM  CUSTOM  DELIVERED
# 2  19663366          -    1 Dec 22, 10:40 AM  CUSTOM  DELIVERED
# 3  19663366          -    1 Dec 22, 10:40 AM  CUSTOM  DELIVERED
# 4  19663366          -    1 Dec 22, 10:40 AM  CUSTOM  DELIVERED
#
#                                         Channel SKU  \
# 0  Ambi_Pur_Car_Freshener_Gel_Refreshing_Lemon_75_g
# 1                                       Car_Power_7
# 2                          dashboard_dresser_250_ml
# 3                              glass_cleaner_250_ml
# 4                                    Konnect_A_Trio
#
#                                          Master SKU             Product Name  \
# 0  Ambi_Pur_Car_Freshener_Gel_Refreshing_Lemon_75_g  Car Freshener Gel Lemon
# 1                                       Car_Power_7              Car Power 7
# ...
