# %%
import pandas as pd
df=pd.read_csv('weather-city.csv')
df
# Out:
#          day      City  temperature  windspeed  event
# 0   01-01-23     Delhi           32          6   Rain
# 1   02-01-23     Delhi           35          7  Sunny
# 2   03-01-23     Delhi           28          2   Snow
# 3   04-01-23    Mumbai           24          7   Snow
# 4   05-01-23    Mumbai           32          4   Rain
# 5   06-01-23    Mumbai           33          8  Sunny
# 6   07-01-23  New York           34          9  Sunny
# 7   08-01-23  New York           35         10  Sunny
# 8   09-01-23  Banglore           36          6  Sunny
# 9   10-01-23  Banglore           37          4  Sunny
# 10  11-01-23   Chennai           42          5  Sunny

# %%
df.groupby('City')
df
# Out:
#          day      City  temperature  windspeed  event
# 0   01-01-23     Delhi           32          6   Rain
# 1   02-01-23     Delhi           35          7  Sunny
# 2   03-01-23     Delhi           28          2   Snow
# 3   04-01-23    Mumbai           24          7   Snow
# 4   05-01-23    Mumbai           32          4   Rain
# 5   06-01-23    Mumbai           33          8  Sunny
# 6   07-01-23  New York           34          9  Sunny
# 7   08-01-23  New York           35         10  Sunny
# 8   09-01-23  Banglore           36          6  Sunny
# 9   10-01-23  Banglore           37          4  Sunny
# 10  11-01-23   Chennai           42          5  Sunny

# %%
for City,data in data:
    print(city)
    print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
#       1 for City,data in data:
# ----> 2     print(city)
#       3     print(data)
#
# NameError: name 'city' is not defined
