# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\Indrajeet Singh\\Documents\\PY files\\Jupyter Program\\data weather.csv')
df.fillna(0,inplace=True)
df
# Out:
#     Unnamed: 0        EST  Temperature  DewPoint  Humidity  \
# 0            0   01-01-16           38        23        52
# 1            1   01-02-16           36        18        46
# 2            2   01-03-16           40        21        47
# 3            3   01-04-16           25         9        44
# 4            4   01-05-16           20        -3        41
# 5            5   01-06-16           33         4        35
# 6            6   01-07-16           39        11        33
# 7            7   01-08-16           39        29        64
# 8            8   01-09-16           44        38        77
# 9            9   01-10-16           50        46        71
# 10          10   01-11-16           33         8        37
# 11          11   01-12-16           35        15        53
# 12          12  1/13/2016           26         4        42
# 13          13  1/14/2016           30        12        47
# 14          14  1/15/2016           43        31        62
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['Temperature'].min()
# Out:
# 20

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      01-09-16
# 9      01-10-16
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mode()
# Out:
# 0    5.0
# 1    6.0
# 2    7.0
# Name: WindSpeedMPH, dtype: float64

# %%
import pandas as pd
data={
    "Name":["Ram","Shyam","Lakhan","Raju","Rajkumar"],
    "Roll No.":["100","101","102","103","104"],
    "Class":["8","9","10","11","12"],
    "Result":["Pass","Pass","Pass","Fail","Pass"],
    "Mark":["98","95","90","30","50"],
    "Grade":["A+","A+","A","E","C"]
}
table=pd.DataFrame(data)
table
# Out:
#        Name Roll No. Class Result Mark Grade
# 0       Ram      100     8   Pass   98    A+
# 1     Shyam      101     9   Pass   95    A+
# 2    Lakhan      102    10   Pass   90     A
# 3      Raju      103    11   Fail   30     E
# 4  Rajkumar      104    12   Pass   50     C

# %%
table.shape
# Out:
# (5, 6)

# %%
table.columns
# Out:
# Index(['Name', 'Roll No.', 'Class', 'Result', 'Mark', 'Grade'], dtype='object')

# %%
table.Name
# Out:
# 0         Ram
# 1       Shyam
# 2      Lakhan
# 3        Raju
# 4    Rajkumar
# Name: Name, dtype: object

# %%
table
# Out:
#        Name Roll No. Class Result Mark Grade
# 0       Ram      100     8   Pass   98    A+
# 1     Shyam      101     9   Pass   95    A+
# 2    Lakhan      102    10   Pass   90     A
# 3      Raju      103    11   Fail   30     E
# 4  Rajkumar      104    12   Pass   50     C

# %%
type(table['Grade'])
# Out:
# pandas.core.series.Series

# %%
table[['Name','Mark','Result']]
# Out:
#        Name Mark Result
# 0       Ram   98   Pass
# 1     Shyam   95   Pass
# 2    Lakhan   90   Pass
# 3      Raju   30   Fail
# 4  Rajkumar   50   Pass

# %%
table
# Out:
#        Name Roll No. Class Result Mark Grade
# 0       Ram      100     8   Pass   98    A+
# 1     Shyam      101     9   Pass   95    A+
# 2    Lakhan      102    10   Pass   90     A
# 3      Raju      103    11   Fail   30     E
# 4  Rajkumar      104    12   Pass   50     C

# %%
table['Mark'].max()
# Out:
# '98'

# %%
table[['Roll No.','Mark','Class']]
# Out:
#   Roll No. Mark Class
# 0      100   98     8
# 1      101   95     9
# 2      102   90    10
# 3      103   30    11
# 4      104   50    12

# %%
table.describe()
# Out:
#        Name Roll No. Class Result Mark Grade
# count     5        5     5      5    5     5
# unique    5        5     5      2    5     4
# top     Ram      100     8   Pass   98    A+
# freq      1        1     1      4    1     2

# %%
table.set_index('Name',inplace=True)
table
# Out:
#          Roll No. Class Result Mark Grade
# Name
# Ram           100     8   Pass   98    A+
# Shyam         101     9   Pass   95    A+
# Lakhan        102    10   Pass   90     A
# Raju          103    11   Fail   30     E
# Rajkumar      104    12   Pass   50     C

# %%
table.reset_index(inplace=True)
table
# Out:
#        Name Roll No. Class Result Mark Grade
# 0       Ram      100     8   Pass   98    A+
# 1     Shyam      101     9   Pass   95    A+
# 2    Lakhan      102    10   Pass   90     A
# 3      Raju      103    11   Fail   30     E
# 4  Rajkumar      104    12   Pass   50     C

# %%
table.loc['Ram']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 table.loc['Ram']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# ...
