# %%
import pandas as pd
data=pd.read_csv('data weather.csv')
data.fillna('no event',inplace=True)
data
# Out:
#     Unnamed: 0        EST  Temperature  DewPoint  Humidity  \
# 0            0   01-01-16           38        23        52
# 1            1   01-02-16           36        18        46
# 2            2   01-03-16           40        21        47
# 3            3   01-04-16           25         9        44
# 4            4   01-05-16           20        -3        41
# 5            5   01-06-16           33         4        35
# 6            6   01-07-16           39        11        33
# 7            7   01-08-16           39        29        64
# 8            8   01-09-16           44        38        77
# 9            9   01-10-16           50        46        71
# 10          10   01-11-16           33         8        37
# 11          11   01-12-16           35        15        53
# 12          12  1/13/2016           26         4        42
# 13          13  1/14/2016           30        12        47
# 14          14  1/15/2016           43        31        62
# ...

# %%
group=data.groupby('Events')
group

# %%
for Events, Events_data in group:
    print(Events)
    print(Events_data)
# Out:
# Fog-Snow
#     Unnamed: 0        EST  Temperature  DewPoint  Humidity  \
# 16          16  1/17/2016           36        23        66
# 22          22  1/23/2016           26        21        78
#
#     Sea Level PressureIn  VisibilityMiles WindSpeedMPH PrecipitationIn  \
# 16                 29.78                8          6.0            0.05
# 22                 29.77                1         16.0            2.31
#
#     CloudCover    Events  WindDirDegrees
# 16           6  Fog-Snow             345
# 22           8  Fog-Snow              42
# Rain
#     Unnamed: 0        EST  Temperature  DewPoint  Humidity  \
# 8            8   01-09-16           44        38        77
# 9            9   01-10-16           50        46        71
# 15          15  1/16/2016           47        37        70
# 26          26  1/27/2016           41        22        45
#
#     Sea Level PressureIn  VisibilityMiles WindSpeedMPH PrecipitationIn  \
# ...

# %%
group.get_group('Snow')
# Out:
#     Unnamed: 0        EST  Temperature  DewPoint  Humidity  \
# 17          17  1/18/2016           25         6        53
# 21          21  1/22/2016           26         6        41
# 23          23  1/24/2016           28        11        53
#
#     Sea Level PressureIn  VisibilityMiles WindSpeedMPH PrecipitationIn  \
# 17                 29.83                9         12.0               T
# 21                 30.21                9     no event            0.01
# 23                 29.92                8          6.0               T
#
#     CloudCover Events  WindDirDegrees
# 17           2   Snow             293
# 21           3   Snow              34
# 23           3   Snow             327

# %%
group.max()
# Out:
# /tmp/ipykernel_2335/1863867792.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   group.max()
#           Unnamed: 0        EST  Temperature  DewPoint  Humidity  \
# Events
# Fog-Snow          22  1/23/2016           36        23        78
# Rain              26  1/27/2016           50        46        77
# Snow              23  1/24/2016           28        11        53
# no event          30  1/31/2016           46        31        64
#
#           Sea Level PressureIn  VisibilityMiles PrecipitationIn  CloudCover  \
# Events
# Fog-Snow                 29.78                8            2.31           8
# Rain                     30.16               10               T           8
# Snow                     30.21                9               T           3
# ...

# %%
group.mean()
# Out:
# /tmp/ipykernel_2335/3928442431.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group.mean()
#           Unnamed: 0  Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# Events
# Fog-Snow   19.000000    31.000000  22.000000  72.000000             29.775000
# Rain       14.500000    45.500000  35.750000  65.750000             29.825000
# Snow       20.333333    26.333333   7.666667  49.000000             29.986667
# no event   14.000000    34.181818  15.590909  47.636364             30.044091
#
#           VisibilityMiles  CloudCover  WindDirDegrees
# Events
# Fog-Snow         4.500000    7.000000      193.500000
# Rain             7.750000    6.250000      209.000000
# Snow             8.666667    2.666667      218.000000
# no event         9.954545    2.272727      262.909091

# %%
 group.describe()
# Out:
#          Unnamed: 0                                                       \
#               count       mean       std   min    25%   50%    75%   max
# Events
# Fog-Snow        2.0  19.000000  4.242641  16.0  17.50  19.0  20.50  22.0
# Rain            4.0  14.500000  8.266398   8.0   8.75  12.0  17.75  26.0
# Snow            3.0  20.333333  3.055050  17.0  19.00  21.0  22.00  23.0
# no event       22.0  14.000000  9.995237   0.0   5.25  12.5  23.00  30.0
#
#          Temperature             ... CloudCover      WindDirDegrees  \
#                count       mean  ...        75%  max          count
# Events                           ...
# Fog-Snow         2.0  31.000000  ...       7.50  8.0            2.0
# Rain             4.0  45.500000  ...       7.25  8.0            4.0
# Snow             3.0  26.333333  ...       3.00  3.0            3.0
# no event        22.0  34.181818  ...       3.00  8.0           22.0
#
#
# ...

# %%
# %matplotlib inline
group.plot()
# Out:
# Events
# Fog-Snow    AxesSubplot(0.125,0.11;0.775x0.77)
# Rain        AxesSubplot(0.125,0.11;0.775x0.77)
# Snow        AxesSubplot(0.125,0.11;0.775x0.77)
# no event    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object
