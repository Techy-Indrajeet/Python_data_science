# %%
import matplotlib.pyplot as plt
import pandas as pd
data={
    "Patient name":["Ram","Shyam","Kuldeep","Manish","Vikash","Shiv","Ramesh"],
    "Patient ID":[11001,11002,11003,11004,11005,11006,11007],
    "Blood Suger":[100,102,103,104,100,99,103]
}
data=pd.DataFrame(data)
data
data.to_csv("patient_report.csv",index=False)

# %%
a=data['Patient name']
b=data['Blood Suger']
plt.xlabel("Patient Names")
plt.ylabel("Suger Level")
plt.title("Patient Suger level report")
plt.plot(a,b,marker='.')
plt.grid()

# %%
report=pd.read_csv('patient_report.csv')
report
# Out:
#   Patient name  Patient ID  Blood Suger
# 0          Ram       11001          100
# 1        Shyam       11002          102
# 2      Kuldeep       11003          103
# 3       Manish       11004          104
# 4       Vikash       11005          100
# 5         Shiv       11006           99
# 6       Ramesh       11007          103

# %%
a=data['Patient name']
b=data['Blood Suger']
plt.hist(b,rwidth=0.95,color='g',orientation='horizontal')
# Out:
# (array([1., 0., 2., 0., 0., 0., 1., 0., 2., 1.]),
#  array([ 99. ,  99.5, 100. , 100.5, 101. , 101.5, 102. , 102.5, 103. ,
#         103.5, 104. ]),
#  <BarContainer object of 10 artists>)
